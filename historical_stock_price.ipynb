# %%
import requests, json
import numpy as np
import pandas as pd

# %%
import pandas as pd
import requests, json

date = '20230501'
stock_no = ['0050','0056']
stock_historical_info = pd.DataFrame()

for ticker in stock_no:
    html = requests.get('https://www.twse.com.tw/exchangeReport/STOCK_DAY?response=json&date=%s&stockNo=%s' % (date,ticker))
    content = json.loads(html.text)
    stock_data = content['data']
    col_name = content['fields']
    df = pd.DataFrame(data=stock_data, columns=col_name)
    df['ticker'] = ticker
    stock_historical_info = pd.concat([stock_historical_info, df])

stock_historical_info
# Out:
#           日期        成交股數         成交金額     開盤價     最高價     最低價     收盤價   漲跌價差  \
# 0  112/05/02   5,572,977  655,524,087  117.45  118.00  117.10  117.70  +0.30
# 1  112/05/03   4,652,271  544,828,139  117.35  117.35  116.80  117.20  -0.50
# 2  112/05/04   3,888,293  455,688,616  117.00  117.50  116.70  117.50  +0.30
# 3  112/05/05   2,550,129  300,346,321  117.70  118.05  117.40  117.80  +0.30
# 4  112/05/08   6,287,398  746,027,147  118.50  118.90  118.35  118.55  +0.75
# 5  112/05/09   4,828,179  573,008,011  118.60  119.00  118.30  118.90  +0.35
# 6  112/05/10   4,685,154  553,250,294  118.80  118.80  117.65  117.80  -1.10
# 7  112/05/11   4,031,551  475,242,643  118.25  118.45  117.55  117.55  -0.25
# 8  112/05/12   4,251,764  497,565,809  117.15  117.50  116.75  117.20  -0.35
# 0  112/05/02  14,076,807  399,222,255   28.25   28.44   28.20   28.44  +0.21
# 1  112/05/03  11,700,143  331,715,503   28.38   28.42   28.28   28.42  -0.02
# ...
